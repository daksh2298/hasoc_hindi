# %%
import json
import csv
from random import shuffle
import copy

# %%
def read_files(files,assign_id=None,placeholder=None):
    all_data=[]
    for file in files:
        file_ptr=open(file)
        reader_dict=csv.DictReader(file_ptr)
        for row in reader_dict:
            row=dict(row)
            data=row['text']
            all_data.append(data)
#     print(all_data[0:5])
    unique_data=list(set(all_data))
    all_data=[]
    if assign_id:
        count=1
        for text in unique_data:
            temp_dic={}
            temp_dic['id_str']='{}{}'.format(placeholder,count)
            temp_dic['text']=text
            temp_dic['len']=len(text)
            if len(text):
                all_data.append(copy.deepcopy(temp_dic))
    else:
        pass
#         create logic for None case
    return all_data

# %%
all_data=read_files(['/Users/daksh/Downloads/ToxicData-2019-07-02.csv'],assign_id=True,placeholder='hasoc_hi_')

# %%
print(len(all_data))
# Out:
# 8470

# %%
all_data[:5]
# Out:
# [{'id_str': 'hasoc_hi_1',
#   'text': 'वो जय श्री राम चिलायेंगे आप जय भीम पर अड़े रहना।',
#   'len': 48},
#  {'id_str': 'hasoc_hi_1', 'text': 'सूअर मौत की खां ', 'len': 16},
#  {'id_str': 'hasoc_hi_1',
#   'text': 'बेटा धोनी के बारे में कुछ बुरा बोले ना तो \nक्रिकेट की कसम तुमारी गांड तोड़ देंगे ',
#   'len': 81},
#  {'id_str': 'hasoc_hi_1',
#   'text': 'चुप रंडी की औलाद, मैच तू देख, तुझे जरूरत है, चला है लोडा एक्सपर्ट बनने...\nइतना gaand मे गुड्डा है तो तू जा के खेल ले lavde',
#   'len': 122},
#  {'id_str': 'hasoc_hi_1',
#   'text': '“Hindus in Kairana said that they were selling off their property to Muslims at throwaway prices.”\n\n#DaraHuaMusalman #डरा_हुआ_मुसलमान \n\nMuslims have seized Kairana: BJP team - The Economic Times ',
#   'len': 195}]

# %%
shuffle(all_data)
file_ptr=open('merge_hindi.json','w')
file_ptr.write(json.dumps(all_data,indent=2))
# Out:
# 5320933

# %%
file_ptr.close()

# %%
file_ptr1=open('ToxicData-2019-06-24.csv')
file_ptr2=open('ToxicData-2019-06-25.csv')
data_file_1=csv.DictReader(file_ptr1)
data_file_2=csv.DictReader(file_ptr2)
all_data=[]
both_files=[data_file_1,data_file_2]
for reader in both_files:
    for row in reader:
        print(dict(row))
        all_data.append(dict(row))

print(len(all_data))
# all_data=data_file_1+data_file_2

# %%
def clean_text(text):
    text=text.replace('"','')
    if text[1]=="'":
        return text[2:-1]
    else:
        return text[1:]

# %%
print(clean_text("b'#GandiNaaliAbuse - we are aghast at this comment @RahulGandhi when will you learnt to respect !!'")[-1])

# %%
count=0
check=0
unique=list(set([(row['text'],row['result']) for row in all_data]))
print(len(set(unique)))
all_data_unique=[{'text':row[0],'result':row[1]} for row in unique]
print(len(all_data_unique))
final_data=[]
for data in all_data_unique:
    temp={}
    text=clean_text(data['text'])
    if len(data)==2:
        check+=1
        if data['result']=='CAG' or data['result']=='OAG':
            count+=1
            temp['id_str']='hasoc_{}'.format(count)
            text=clean_text(data['text'])
#             print(text)
            temp['text']=text
            final_data.append(temp)
        else:
            pass
    else:
        print()
        print('!!!!!!!!!ERROR IN THE LINE!!!!!!!!!!!')
        print()
print(len(final_data))
# for line in all_data:
#     splited=line.split(',')
#     if len(splited) == 3:
#         count+=1
#         text,judgement=line.split()[0],line.split()[-1]
#     else:
#         print(count)
#         print(splited[0])
# print(count)

# %%
len(final_data)

# %%
for data in final_data:
    data['len']=len(data['text'])

# %%
len(final_data)

# %%
merge_file=open('merge.json')

# %%
merge_json=json.load(merge_file)

# %%
len(merge_json)

# %%
merge_json+=final_data

# %%
shuffle(merge_json)
len(merge_json)

# %%
dump_data=json.dumps(merge_json,indent=4)

# %%
merge_file.close()

# %%
merge_file=open('merge.json','w')

# %%
merge_file.write(dump_data)

# %%
merge_file.close()

# %%
merge_file=open('merge.json')

# %%
merge_json=json.load(merge_file)

# %%
len(merge_json)

# %%
for i in range(1,5):
    print()

# %%
5882/5

# %%
temp_dump=json.dumps(final_data,indent=4)
file=open('temp.json','w')

# %%
file=open('temp.json','w')
file.write(temp_dump)
file.close()

# %% [markdown]
# # Get intercoder agreement

# %%
import sqlite3

# %%
conn=sqlite3.connect('../hasoc.db')

# %%
cursor=conn.cursor()

# %%
all_tweets=cursor.execute('SELECT * FROM annoted_tweets')

# %%
def clean_data(data):
    data_clean = []
    # print(li)
    for row in data:
        row_li = list(row)
        for column in row_li:
            if column == None:
                row_li.remove(column)
            else:
                pass
        data_clean.append(row_li)

    final_data = []
    count_double = 0
    for data in data_clean:
        updated = [d for d in data if d]
        if len(updated[3:]) > 2:
            # print(updated[1], updated[3:-1])
            count_double += 1
        final_data.append(updated[:-1])
    print('double count', count_double)
    return final_data, count_double


def get_same_annots(data):
    same_annots = []
    count_double = 0
    for row in data:
        row_unique = []
        if 'en' in row:
            row.remove('en')
        if len(row) > 4:
            count_double += 1
            row_unique += row[0:3]
            set_judgement = set(row[3:])
            if len(set_judgement) == 1:
                set_judgement = list(set_judgement)
                row_unique.append(set_judgement[0])
                same_annots.append(row_unique)

    return same_annots, count_double

# %%
final_data,double_count=clean_data(all_tweets)

# %%
len(final_data)

# %%
print(final_data[0])

# %%
results=[row[1:2]+row[3:] for row in final_data]

# %%
len(results)

# %%
def get_agg():
    all_tasks={
        'task_1':[],
        'task_2':[],
        'task_3':[]
    }
    for result in results:
        count=1
        temp_1,temp_2,temp_3=[],[],[]
        for annot in result[1:]:
            if annot != 'en':
                annot=annot.split('\t')
                temp_1.append(annot[0])
                temp_2.append(annot[1])
                temp_3.append(annot[2])
        all_tasks['task_1'].append(tuple(set(temp_1)))
        all_tasks['task_2'].append(tuple(set(temp_2)))
        all_tasks['task_3'].append(tuple(set(temp_3)))
    for task in all_tasks:
        all_tasks[task]=[result for result in all_tasks[task] if len(result)==1]
    for task in all_tasks:
        print(task,len(all_tasks[task]))

# %%
get_agg()

# %%
count_1=0
for an in all_tasks['task_1']:
    if len(an)==1:
        count_1+=1
    else:
        pass
print(count_1,len(all_tasks['task_1']))

# %%
count_2=0
temp=[]
for an in all_tasks['task_2']:
#     print(an[0])
    if an[0]!='None':
        temp.append(an[0])
    if len(an)==1 and an[0]!='None':
        count_2+=1
    else:
        pass
    
print(count_2/len(temp))

# %%
count_3=0
for an in all_tasks['task_3']:
    if len(an)==1:
        count_3+=1
    else:
        pass
print(count_3/len(all_tasks['task_3']))

# %% [markdown]
# # Get single annotated tweets

# %%
import sqlite3
import copy
import json
def conn_db():
    return sqlite3.connect('../hasoc.db', check_same_thread=False)

def get_single_annots(data=None):
    conn = conn_db()
    cursor = conn.cursor()
    query = 'SELECT * FROM annoted_tweets'
    cursor.execute(query)
    rows = cursor.fetchall()
    print(len(rows))
    new_data=[]
    data=[]
    for row in rows:
        temp=list(row)
        data.append(temp)
    for li in data:
        l=[item for item in li if item is not None]
        if len(l)==5:
            new_data.append(l)
    print(len(new_data))
    return new_data

# %%
single=get_single_annots()
# Out:
# 5861
# 472

# %%
with open('annoted_tweets.json') as json_file_ptr:
    annotated_data=json.load(json_file_ptr)

# %%
for user in annotated_data:
    annotated_data[user]['to_be_annotated']=[]
    annotated_data[user]['annoted_count']=len(annotated_data[user]['annoted_tweets'])
    annotated_data[user]['reported_count']=len(annotated_data[user]['reported_tweets'])
    annotated_data[user]['total_assigned']=annotated_data[user]['start_end'][1]-annotated_data[user]['start_end'][0]

# %%
annotated_data.keys()
# Out:
# dict_keys(['aditya_hasoc', 'admin', 'bhargav_hasoc', 'daksh2_hasoc', 'daksh_hasoc', 'devarshi_hasoc', 'dhruv_hasoc', 'kush_hasoc', 'meet_hasoc', 'mohana_hasoc', 'parth_hasoc', 'spandan_hasoc', 'suru_hasoc'])

# %%
split_dict={'aditya_hasoc': 305, 'admin': 305, 'bhargav_hasoc': 0, 'kush_hasoc': 1000, 'daksh2_hasoc': 305, 'daksh_hasoc': 305, 'devarshi_hasoc': 0, 'dhruv_hasoc': 0, 'meet_hasoc': 305, 'mohana_hasoc': 0, 'parth_hasoc': 305, 'spandan_hasoc': 305, 'suru_hasoc': 0}
for user in annotated_data:
    split_dict[user]=int(input('Enter amount of tweet to be allocated for {}:- '.format(user)))
print(split_dict)
assigned_ids=[]
for user in annotated_data:
    annotated_reported_list=annotated_data[user]['annoted_tweets']+annotated_data[user]['reported_tweets']
    annotated_data[user]['to_be_annotated']=[]
    for tweet in single:
        if tweet[1] not in annotated_reported_list and split_dict[user] != 0 and tweet[1] not in assigned_ids:
            annotated_data[user]['to_be_annotated'].append(tweet[1])
            assigned_ids.append(tweet[1])
            split_dict[user]-=1
    annotated_data[user]['total_assigned']=len(annotated_data[user]['to_be_annotated'])
# Out:
# Enter amount of tweet to be allocated for aditya_hasoc:- 95
# Enter amount of tweet to be allocated for admin:- 95
# Enter amount of tweet to be allocated for bhargav_hasoc:- 0
# Enter amount of tweet to be allocated for daksh2_hasoc:- 92
# Enter amount of tweet to be allocated for daksh_hasoc:- 92
# Enter amount of tweet to be allocated for devarshi_hasoc:- 0
# Enter amount of tweet to be allocated for dhruv_hasoc:- 0
# Enter amount of tweet to be allocated for kush_hasoc:- 0
# Enter amount of tweet to be allocated for meet_hasoc:- 0
# Enter amount of tweet to be allocated for mohana_hasoc:- 0
# Enter amount of tweet to be allocated for parth_hasoc:- 92
# Enter amount of tweet to be allocated for spandan_hasoc:- 0
# Enter amount of tweet to be allocated for suru_hasoc:- 0
# {'aditya_hasoc': 95, 'admin': 95, 'bhargav_hasoc': 0, 'kush_hasoc': 0, 'daksh2_hasoc': 92, 'daksh_hasoc': 92, 'devarshi_hasoc': 0, 'dhruv_hasoc': 0, 'meet_hasoc': 0, 'mohana_hasoc': 0, 'parth_hasoc': 92, 'spandan_hasoc': 0, 'suru_hasoc': 0}

# %%
split_dict
# Out:
# {'aditya_hasoc': 0,
#  'admin': 0,
#  'bhargav_hasoc': 0,
#  'kush_hasoc': 0,
#  'daksh2_hasoc': 0,
#  'daksh_hasoc': 0,
#  'devarshi_hasoc': 0,
#  'dhruv_hasoc': 0,
#  'meet_hasoc': 0,
#  'mohana_hasoc': 0,
#  'parth_hasoc': 0,
#  'spandan_hasoc': 0,
#  'suru_hasoc': 0}

# %%
dump_data=json.dumps(annotated_data,indent=4)
file_ptr=open('temp.json','w')
file_ptr.write(dump_data)
file_ptr.close()

# %%
3133/8

# %%
2133/7

# %%
data=json.load(open('annoted_tweets.json'))

# %%
all_tweets=[]
total=0
for user in data:
    all_tweets+=data[user]["annoted_tweets"]+data[user]["to_be_annotated"]+data[user]["reported_tweets"]
print(len(set(all_tweets)))
set_all=set(all_tweets)

# %%
merge=json.load(open('merge.json'))

# %%
len(merge)

# %%
all_ids=[tweet['id_str'] for tweet in merge]

# %%
len(all_ids)

# %%
remaining=list(set(all_ids).difference(set_all))

# %%
conn = conn_db()
cursor = conn.cursor()
query = 'SELECT * FROM annoted_tweets'
cursor.execute(query)
rows = cursor.fetchall()
db_ids=[row[1] for row in rows]

# %%
set(set_all).difference(db_ids)

# %%
360/4

# %%
annoted_data=json.load(open('annoted_tweets.json'))
final=[]
for user in annoted_data:
    final+=annoted_data[user]["annoted_tweets"]+annoted_data[user]["to_be_annotated"]+annoted_data[user]["reported_tweets"]

len(set(final))

# %%
start=0
for user in ['aditya_hasoc',
 'admin',
 'kush_hasoc',
 'daksh2_hasoc',
 'daksh_hasoc',
 'meet_hasoc',
 'parth_hasoc',
 'spandan_hasoc']:
    print(user)
    print(len(annoted_data[user]['to_be_annotated']))
    annoted_data[user]['to_be_annotated']+=remaining[start:start+90]
    print(len(annoted_data[user]['to_be_annotated']))
    start+=90

# %%
all_tweets=[]
total=0
for user in annoted_data:
    all_tweets+=annoted_data[user]["annoted_tweets"]+annoted_data[user]["to_be_annotated"]+annoted_data[user]["reported_tweets"]

# %%
len(set(all_tweets))

# %%
for user in annoted_data:
    annoted_data[user]['annoted_count']=len(annoted_data[user]['annoted_tweets'])
    annoted_data[user]['reported_count']=len(annoted_data[user]['reported_tweets'])
    annoted_data[user]['total_assigned']=len(annoted_data[user]["to_be_annotated"])

# %%
with open("annoted_tweets.json", 'w') as json_file:
    json.dump(annoted_data, json_file, indent=4)

# %%
conn = conn_db()
cursor = conn.cursor()
query = 'SELECT * FROM annoted_tweets'
cursor.execute(query)
rows = cursor.fetchall()
print(len(rows))
new_data=[]
data=[]

# %%
all_id_annots=[row[1] for row in rows]

# %%
len(all_id_annots)

# %%
import json
temp=open('merge.json')
data= json.load(temp)
# print(data[0:5])
all_id_merge=[row['id_str'] for row in data]

# %%
len(all_id_merge)

# %%
set(all_id_merge).difference(all_id_annots)

# %%
data=[]
new_data=[]
for row in rows:
    temp=list(row)
    data.append(temp)

print(data[0])
for li in data:
    l=[item for item in li if item is not None]
    if len(l)>5:
        new_data.append(l)

# %%
len(new_data)

# %%
count=0
for d in new_data:
    if 'en' in d:
        d.remove('en')
    if 'None' in d:
        d.remove('None')
    if len(d[3:])>=2:
#         print(d[3:])
        count+=1
print(count)

# %%
annots=open('annoted_tweets_08_7.json')
annot_data=json.load(annots)
for user in annot_data:

# %%
l=[1,1,23,23,4,5,7,7]
l=[]
for x in l:
    if x not in l:
    l.append(x)

# %%
import json
temp=open('merge.json')
data= json.load(temp)

# %%
len(data)

# %%
file=open('merge.txt','w')
lines=''
for d in data:
    text=d['text'].replace('\n',' ').replace('\r',' ')
    lines+='{}\t{}\n'.format(d['id_str'],text)

# %%
file.write(lines)
file.close()

# %%
import json
import sqlite3

# %%
conn = sqlite3.connect('../hasoc.db')
cursor = conn.cursor()
query = 'SELECT * FROM annoted_tweets'
cursor.execute(query)
rows = cursor.fetchall()
print(len(rows))
new_data=[]
data=[]

# %%
import json
import sqlite3
conn = sqlite3.connect('../hasoc.db')
cursor = conn.cursor()
query = 'SELECT * FROM annoted_tweets'
cursor.execute(query)
rows = cursor.fetchall()
print(len(rows))
new_data=[]
data=[]
def clean_data(data):
    data_clean = []
    # print(li)
    for row in data:
        row_li = list(row)
        for column in row_li:
            if column == None:
                row_li.remove(column)
            else:
                pass
        data_clean.append(row_li)

    final_data = []
    count_double = 0
    for data in data_clean:
        updated = [d for d in data if d and d != 'None']
        if len(updated[3:]) > 2:
            # print(updated[1], updated[3:-1])
            count_double += 1
        final_data.append(updated[:-1])
#     print('double count', count_double)
    return final_data, count_double

def get_agg(data):
    all_tasks = {
        'task_1': [],
        'task_2': [],
        'task_3': [],
        'task_1_un': [],
        'task_2_un': [],
        'task_3_un': []
    }
    results, ignore = clean_data(data)
    for result in results:
        count = 1
        temp_1, temp_2, temp_3 = [], [], []
        for annot in result[3:]:
            if annot != 'en' and annot != 'hi':
                annot = annot.split('\t')
                if len(annot)<3:
                    print(result)
                    continue
                temp_1.append(annot[0])
                temp_2.append(annot[1])
                temp_3.append(annot[2])
        all_tasks['task_1'].append(tuple(set(temp_1)))
        all_tasks['task_2'].append(tuple(set(temp_2)))
        all_tasks['task_3'].append(tuple(set(temp_3)))
    for task in ['task_1', 'task_2', 'task_3']:
        temp = [result for result in all_tasks[task] if len(result) == 1]
        # print('--------', temp)
        all_tasks[task + '_un'] = temp
    agg = []
    for task in ['task_1', 'task_2', 'task_3']:
        agg.append('%.2f' % (len(all_tasks[task + '_un']) / len(all_tasks[task]) * 100))
#     print(agg)
    return all_tasks


all_tasks=get_agg(rows)


resp1=[]
for result in all_tasks['task_1']+all_tasks['task_2']+all_tasks['task_3']:
    if len(result):
        resp1.append(result[0])
#     else len(result):
#         task11.append(result[0])
resp2=[]
for result in all_tasks['task_1']+all_tasks['task_2']+all_tasks['task_3']:
    if len(result)>1:
        resp2.append(result[1])
    elif len(result):
        resp2.append(result[0])
# print(task11.count('HOF'),task11.count('NOT'),task11.count('HATE'),task11.count('OFFN'),task11.count('PRFN'),task11.count('None'),task11.count('UNT'),task11.count('TIN'),task11.count('NULL'))
print(len(set(resp1)),len(set(resp1)))
print('{} {}'.format('USER 1'.center(38),'USER 2'.center(30)))

for an in ['NOT','HOF','HATE','OFFN','PRFN','None','UNT','TIN','NULL']:
    print('{} {} {}'.format(an,str(resp1.count(an)).center(30),str(resp2.count(an)).center(38)))




analysis={
    1:{
        'count_task_1':{
            'NOT':0,
            'HOF':0,
        },
        'count_task_2':{
            'HATE':0,
            'OFFN':0,
            'PRFN':0,
            'None':0,
        },
        'count_task_3':{
            'UNT':0,
            'TIN':0,
            'NULL':0
        }
    },
    2:{
        'count_task_1':{
            'NOT':0,
            'HOF':0,
        },
        'count_task_2':{
            'HATE':0,
            'OFFN':0,
            'PRFN':0,
            'None':0,
        },
        'count_task_3':{
            'UNT':0,
            'TIN':0,
            'NULL':0
        }
    }
}


# for user in analysis:
#     for task in ['task_1','task_2','task_3']:
#         for result in all_tasks[task]:
#             if len(result)<1:
#                 continue
#             elif len(result)==1 or user == 1:
#                 analysis[user]['count_{}'.format(task)][result[0]]+=1
# #                 count_task1[result[0]]+=1
#             else:
#                 analysis[user]['count_{}'.format(task)][result[1]]+=1

# for result in all_tasks['task_1']:
#     if len(result)<1:
#         print(result)
#         continue
#     elif len(result)==1:
#         count_task1[result[0]]+=1
#     else:
#         count_task1[result[1]]+=1
# for result in all_tasks['task_2']:
#     if len(result)<1:
#         print(result)
#         continue
#     elif len(result)==1:
#         count_task2[result[0]]+=1
#     else:
#         count_task2[result[1]]+=1
# for result in all_tasks['task_3']:
#     if len(result)<1:
#         print(result)
#         continue
#     elif len(result)==1:
#         count_task3[result[0]]+=1
#     else:
#         count_task3[result[1]]+=1
# print(analysis)
# Out:
# 5861
# 9 9
#                 USER 1                             USER 2
# NOT              3105                               4448
# HOF              2656                               1313
# HATE              1347                               454
# OFFN              199                                774
# PRFN              839                                362
# None              3376                               4171
# UNT              259                                215
# TIN              2397                               1115
# NULL              3105                               4431

# %%
{1: {'count_task_1': {'NOT': 4448, 'HOF': 1313}, 'count_task_2': {'HATE': 375, 'OFFN': 507, 'PRFN': 431, 'None': 4448}, 'count_task_3': {'UNT': 372, 'TIN': 1115, 'NULL': 4274}}, 2: {'count_task_1': {'NOT': 3105, 'HOF': 2656}, 'count_task_2': {'HATE': 1401, 'OFFN': 487, 'PRFN': 768, 'None': 3105}, 'count_task_3': {'UNT': 102, 'TIN': 2380, 'NULL': 3279}}}

# %%
analysis={
    1:{
        'count_task_1':{
            'NOT':0,
            'HOF':0,
        },
        'count_task_2':{
            'HATE':0,
            'OFFN':0,
            'PRFN':0,
            'None':0,
        },
        'count_task_3':{
            'UNT':0,
            'TIN':0,
            'NULL':0
        }
    },
    2:{
        'count_task_1':{
            'NOT':0,
            'HOF':0,
        },
        'count_task_2':{
            'HATE':0,
            'OFFN':0,
            'PRFN':0,
            'None':0,
        },
        'count_task_3':{
            'UNT':0,
            'TIN':0,
            'NULL':0
        }
    }
}


for user in analysis:
    for task in ['task_1','task_2','task_3']:
        for result in all_tasks[task]:
            if len(result)<1:
                continue
            elif len(result)==1 or user == 1:
                analysis[user]['count_{}'.format(task)][result[0]]+=1
#                 count_task1[result[0]]+=1
            else:
                analysis[user]['count_{}'.format(task)][result[1]]+=1

# for result in all_tasks['task_1']:
#     if len(result)<1:
#         print(result)
#         continue
#     elif len(result)==1:
#         count_task1[result[0]]+=1
#     else:
#         count_task1[result[1]]+=1
# for result in all_tasks['task_2']:
#     if len(result)<1:
#         print(result)
#         continue
#     elif len(result)==1:
#         count_task2[result[0]]+=1
#     else:
#         count_task2[result[1]]+=1
# for result in all_tasks['task_3']:
#     if len(result)<1:
#         print(result)
#         continue
#     elif len(result)==1:
#         count_task3[result[0]]+=1
#     else:
#         count_task3[result[1]]+=1
print(analysis)

# %%
count_task1,count_task2,count_task3

# %%
len(all_tasks['task_1_un'])

# %%
4418/5861

# %%
a1=({'NOT': 3105, 'HOF': 2656},
 {'HATE': 1220, 'OFFN': 199, 'PRFN': 703, 'None': 3639},
 {'UNT': 355, 'TIN': 1468, 'NULL': 3938})
a2=({'NOT': 4448, 'HOF': 1313},
 {'HATE': 580, 'OFFN': 795, 'PRFN': 488, 'None': 3898},
 {'UNT': 119, 'TIN': 2027, 'NULL': 3615})

# %%
all_tasks['task_1']

# %%
task11=[]
for result in all_tasks['task_1']:
    if len(result)>1:
        task11.append(result[1])
    elif len(result):
        task11.append(result[0])
task11.count('HOF'),task11.count('NOT')
# [result[0] for result in all_tasks['task_1']]

# %%
(2656, 3105)

# %% [markdown]
# # Create temporary TSV ENGLISH

# %%
import json
import sqlite3
conn_final = sqlite3.connect('../hasoc_final_final.db')
cursor_final=conn_final.cursor()
cursor_final.execute('SELECT * FROM annoted_tweets')

# %%
all_tweets=cursor_final.fetchall()

# %%
all_tweets=clean_data(all_tweets)[0]

# %%
import pandas as pd

# %%
# final_data=[]
data='id\tid_str\ttext\tuser1_task1\tuser1_task2\tuser1_task3\tuser2_task1\tuser2_task2\tuser2_task3\tuser3_task1\tuser3_task2\tuser3_task3\n'
for tweet in all_tweets:
    tweet=list(tweet)
    if 'en' in tweet:
        tweet.remove('en')
    if 'hi' in tweet:
        tweet.remove('hi')
    if 'None' in tweet:
        tweet.remove('None')
    tweet[2]=tweet[2].replace('\n',' ').replace('\r',' ')
    tweet[0]=str(tweet[0])
    data+='\t'.join(tweet)+'\n'
# print(data)

file_ptr=open('temp.tsv','w')
file_ptr.write(data)
file_ptr.close()
# df=pd.DataFrame(data=all_tweets)

# %%
df=pd.read_csv('temp.tsv',sep='\t')

# %%
df
# Out:
#         id               id_str  \
# 0        7  1140424458991259648
# 1        8  1139542724036694017
# 2        9  1140326741224783872
# 3       10  1136921850359848960
# 4       11  1139597122683265026
# 5       12  1139476832409944064
# 6       13  1139666404150562818
# 7       14  1140522202300911616
# 8       15  1139687317394751489
# 9       16  1140130429925642241
# 10      17  1139769323180810240
# 11      18  1138658530913902593
# 12      19  1139047262045331456
# 13      20  1138488101108629504
# 14      21  1140498832955969536
# 15      22  1136978636639223808
# 16      23  1138068660944117765
# 17      24  1139384903261290496
# 18      25  1140240731317161984
# 19      26  1139482207356145665
# 20      27  1139780556114337793
# 21      28  1140419987921915904
# 22      29  1139482032973631489
# 23      30  1139329055587753984
# 24      31  1139860224427331586
# 25      32  1139805273210511362
# 26      33  1139798586319749120
# 27      34  1139537197231747073
# 28      35  1140631342390173696
# 29      36  1137257860239245312
# ...    ...                  ...
# 5831  5839  1140084168505909248
# 5832  5840  1129375257926754304
# 5833  5841  1140210952060542978
# 5834  5842  1139562874945208321
# 5835  5843  1139830897660661761
# 5836  5844  1139500730656542720
# 5837  5845  1138646234065985536
# 5838  5846  1139557445041156096
# 5839  5847  1139751314676518913
# 5840  5848  1139995112774066178
# 5841  5849  1139732684983287808
# 5842  5850  1139471139602718721
# 5843  5851  1140446740233019392
# 5844  5852  1138412324681846784
# 5845  5853  1139640909761585152
# 5846  5854  1138898056106188800
# 5847  5855  1140250572790161410
# 5848  5856  1140430417775996928
# 5849  5857  1139515469432418309
# 5850  5858  1139866757127114753
# 5851  5859  1139784868810784768
# 5852  5860  1140096020585435136
# 5853  5861  1139905969436184577
# 5854  5862  1138619286115835904
# 5855  5863  1140463856470429696
# 5856  5864  1140492717115564032
# 5857  5865  1139669253601341441
# 5858  5866  1138628508236693505
# 5859  5867  1139635280049246208
# 5860  5868  1137922499415564288
#
#                                                    text user1_task1  \
# 0     @RossThomson_MP Imitation of a tweet, flattery...         NOT
# 1     @Sarah_SKG_1983 The beach is calling! Weekend ...         HOF
# 2     It's clear to see why @BorisJohnson has not ta...         HOF
# 3     #DhoniKeepsTheGlove | WATCH: Sports Minister K...         NOT
# 4     @politico No. We should remember very clearly ...         HOF
# 5     @cricketworldcup Guess who would be the winner...         NOT
# 6     @funder #JohnMcCainDay Thanks for fund raising...         HOF
# 7     Corbyn is too politically intellectual for #Bo...         NOT
# 8     All the best to #TeamIndia for another swimmin...         NOT
# 9     @kellymiller513 @TheRealOJ32 I hope you rememb...         NOT
# 10    @ICC Latest design of #WC2019 trophy. #CWC2019...         NOT
# 11    @kenjilopezalt Was it the frozen meal line, th...         HOF
# 12    #ADOS #trendingnow #blacklivesmatter #justice ...         HOF
# 13    Thanks for your support! Wow 600k. Graffiti ha...         NOT
# 14    He will metaphorically hang himself all on his...         HOF
# 15    By wearing the #BalidaanBadge over his gloves ...         NOT
# 16    Mahendra Singh Dhoni's love for the Nation, Ar...         NOT
# 17    A billion Cricket fans waited four years to wa...         HOF
# 18    This is what I hate most about politics today:...         HOF
# 19    Happy #JohnMcCainDay #JohnMcCainDayJune14th   ...         NOT
# 20    Dr. Kafeel arranged oxygen cylinders with his ...         HOF
# 21    I don’t know how much more I can take! 45 is a...         HOF
# 22    #ShameOnICC@ICC WINNER TEAM-RAIN  ICC RUN UP T...         NOT
# 23    How do you say 'Gulf of Tonkin' in 2019? Oh ye...         HOF
# 24    @psarkar2111 We need correct action from docto...         NOT
# 25    @narendramodi  @pmoindia_namo  @narendramodi  ...         NOT
# 26    What is stopping Modi Govt To Impose president...         NOT
# 27    Benedict Arnold used debt and being passed ove...         HOF
# 28    Next in line to the Tory dictatorship, BoJo, w...         HOF
# 29    ICC denies request from BCCI to allow MSD wear...         NOT
# ...                                                 ...         ...
# 5831  @TeaPainUSA Wondering if NYT has now endangere...         NOT
# 5832  #SanctuaryCity proponents #jennydurkan #pramil...         NOT
# 5833  #IMAFraud was the wel planned Economic Offense...         HOF
# 5834  Now you understand who I am really? Ha Ha  #Do...         NOT
# 5835  #DoctorsFightBack #MamataFrustrated    It's hi...         NOT
# 5836  #ShameOnICC  ICC is earning billions from this...         NOT
# 5837  @44mmvvpp @harrisbw49 Gas Station Toilet 45/40...         NOT
# 5838  She’s probably lying about leaving so people d...         HOF
# 5839  I’d believe a talking anus over trump. 😂😂😂😂 #N...         NOT
# 5840  @realDonaldTrump You having been squealing lik...         NOT
# 5841  #DoctorsFightBack this is new India agitating ...         HOF
# 5842  Then #ABrandNewDayOUTNOW was released and it i...         NOT
# 5843  @TheRealOJ32 @KrisJenner You do know absolutel...         NOT
# 5844  @RepDLamborn Liar! You have no rights to make ...         NOT
# 5845  @_yogirlt Only to be informed of his complete ...         HOF
# 5846  #IdiotTrump Claims His Own Polls Are Fake And ...         NOT
# 5847  @MeetThePress @SteveScalise Really Steve @Spea...         NOT
# 5848  @marcorubio Mohamed Bin Salaam - #murderer #li...         HOF
# 5849  It's a crime to hit a ONDUTY POLICE OFFICER bu...         NOT
# 5850  @realDonaldTrump #fucktrump you’re a disgrace ...         HOF
# 5851  @cricketworldcup @ICC This world cup 19 should...         HOF
# 5852  @EllisFan14 Only if he finds you. #OJSimpson #...         NOT
# 5853  @BettyBowers @realDonaldTrump Market crash com...         NOT
# 5854               @HamAnalysis Shame on him! #dickhead         NOT
# 5855  #DictatorTrump   #DefeatGOPin2020 #DitchMitch ...         NaN
# 5856  Why bother to leave a spot open for Johnson.  ...         NaN
# 5857  @realDonaldTrump Poll numbers in PA are really...         NaN
# 5858  Trump's trade war is here to stay. Companies l...         NaN
# 5859  In honor of #JohnMCainDay I think I should buy...         NaN
# 5860  Let’s just hope that one of our own #Boston fa...         NaN
#
#      user1_task2 user1_task3 user2_task1 user2_task2 user2_task3 user3_task1  \
# 0           None         NaN         NOT        None         NaN         HOF
# 1           HATE         TIN         NOT        None         NaN         NOT
# 2           HATE         TIN         NOT        None         NaN         HOF
# 3           None         NaN         NOT        None         NaN         NOT
# 4           HATE         TIN         HOF        HATE         TIN         HOF
# 5           None         NaN         NOT        None         NaN         NaN
# 6           OFFN         TIN         NOT        None         NaN         NaN
# 7           None         NaN         NOT        None         NaN         NaN
# 8           None         NaN         NOT        None         NaN         NaN
# 9           None         NaN         NOT        None         NaN         NaN
# 10          None         NaN         NOT        None         NaN         NaN
# 11          PRFN         TIN         NOT        None         NaN         NaN
# 12          PRFN         TIN         HOF        PRFN         TIN         NaN
# 13          None         NaN         NOT        None         NaN         NaN
# 14          OFFN         TIN         NOT        None         NaN         NaN
# 15          None         NaN         NOT        None         NaN         NOT
# 16          None         NaN         NOT        None         NaN         NOT
# 17          HATE         TIN         HOF        HATE         UNT         NOT
# 18          PRFN         UNT         HOF        PRFN         UNT         HOF
# 19          None         NaN         HOF        PRFN         TIN         NOT
# 20          HATE         TIN         HOF        HATE         TIN         NOT
# 21          HATE         TIN         HOF        HATE         TIN         HOF
# 22          None         NaN         NOT        None         NaN         NaN
# 23          HATE         TIN         HOF        PRFN         TIN         HOF
# 24          None         NaN         HOF        OFFN         TIN         NOT
# 25          None         NaN         NOT        None         NaN         NOT
# 26          None         NaN         HOF        OFFN         TIN         NOT
# 27          HATE         TIN         HOF        HATE         TIN         NOT
# 28          HATE         TIN         HOF        HATE         TIN         NOT
# 29          None         NaN         NOT        None         NaN         NOT
# ...          ...         ...         ...         ...         ...         ...
# 5831        None         NaN         NaN         NaN         NaN         NaN
# 5832        None         NaN         NaN         NaN         NaN         NaN
# 5833        HATE         TIN         NaN         NaN         NaN         NaN
# 5834        None         NaN         NaN         NaN         NaN         NaN
# 5835        None         NaN         NaN         NaN         NaN         NaN
# 5836        None         NaN         NaN         NaN         NaN         NaN
# 5837        None         NaN         NaN         NaN         NaN         NaN
# 5838        OFFN         TIN         NaN         NaN         NaN         NaN
# 5839        None         NaN         NaN         NaN         NaN         NaN
# 5840        None         NaN         NaN         NaN         NaN         NaN
# 5841        HATE         TIN         NaN         NaN         NaN         NaN
# 5842        None         NaN         NaN         NaN         NaN         NaN
# 5843        None         NaN         NaN         NaN         NaN         NaN
# 5844        None         NaN         NaN         NaN         NaN         NaN
# 5845        PRFN         TIN         NaN         NaN         NaN         NaN
# 5846        None         NaN         NaN         NaN         NaN         NaN
# 5847        None         NaN         NaN         NaN         NaN         NaN
# 5848        OFFN         TIN         NaN         NaN         NaN         NaN
# 5849        None         NaN         NaN         NaN         NaN         NaN
# 5850        PRFN         TIN         NaN         NaN         NaN         NaN
# 5851        PRFN         TIN         NaN         NaN         NaN         NaN
# 5852        None         NaN         NaN         NaN         NaN         NaN
# 5853        None         NaN         NaN         NaN         NaN         NaN
# 5854        None         NaN         NaN         NaN         NaN         NaN
# 5855         NaN         NaN         NaN         NaN         NaN         NaN
# 5856         NaN         NaN         NaN         NaN         NaN         NaN
# 5857         NaN         NaN         NaN         NaN         NaN         NaN
# 5858         NaN         NaN         NaN         NaN         NaN         NaN
# 5859         NaN         NaN         NaN         NaN         NaN         NaN
# 5860         NaN         NaN         NaN         NaN         NaN         NaN
#
#      user3_task2 user3_task3
# 0           OFFN         TIN
# 1           None         NaN
# 2           PRFN         TIN
# 3           None         NaN
# 4           HATE         TIN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15          None         NaN
# 16          None         NaN
# 17          None         NaN
# 18          PRFN         TIN
# 19          None         NaN
# 20          None         NaN
# 21          HATE         TIN
# 22           NaN         NaN
# 23          PRFN         TIN
# 24          None         NaN
# 25          None         NaN
# 26          None         NaN
# 27          None         NaN
# 28          None         NaN
# 29          None         NaN
# ...          ...         ...
# 5831         NaN         NaN
# 5832         NaN         NaN
# 5833         NaN         NaN
# 5834         NaN         NaN
# 5835         NaN         NaN
# 5836         NaN         NaN
# 5837         NaN         NaN
# 5838         NaN         NaN
# 5839         NaN         NaN
# 5840         NaN         NaN
# 5841         NaN         NaN
# 5842         NaN         NaN
# 5843         NaN         NaN
# 5844         NaN         NaN
# 5845         NaN         NaN
# 5846         NaN         NaN
# 5847         NaN         NaN
# 5848         NaN         NaN
# 5849         NaN         NaN
# 5850         NaN         NaN
# 5851         NaN         NaN
# 5852         NaN         NaN
# 5853         NaN         NaN
# 5854         NaN         NaN
# 5855         NaN         NaN
# 5856         NaN         NaN
# 5857         NaN         NaN
# 5858         NaN         NaN
# 5859         NaN         NaN
# 5860         NaN         NaN
#
# [5861 rows x 12 columns]

# %%
for col in df.columns[3:9]:
    print(df[col].value_counts())
# Out:
# NOT    3617
# HOF    2229
# Name: user1_task1, dtype: int64
# None    3617
# HATE    1143
# PRFN     663
# OFFN     423
# Name: user1_task2, dtype: int64
# TIN    1999
# UNT     230
# Name: user1_task3, dtype: int64
# NOT    3345
# HOF    1331
# Name: user2_task1, dtype: int64
# None    3345
# OFFN     488
# HATE     446
# PRFN     397
# Name: user2_task2, dtype: int64
# TIN    1177
# UNT     154
# Name: user2_task3, dtype: int64

# %%
len(all_tweets)
# Out:
# 5861

# %%
def get_same_annots(data):
    same_annots = []
    diff_annots=[]
    count_double = 0
    for row in data:
        row_unique = []
        if 'en' in row:
            row.remove('en')
        if 'hi' in row:
            row.remove('hi')
        if 'None' in row:
            row.remove('None')
        if len(row) > 3:
            count_double += 1
            row_unique += row
            set_judgement = set(row[3:])
            if len(set_judgement) == 1:
                set_judgement = list(set_judgement)
                row_unique.append(set_judgement[0])
                same_annots.append(row_unique[0:4])
            else:
                diff_annots.append(row_unique)

    return same_annots,diff_annots

# %%
same,diff=get_same_annots(all_tweets)

# %%
len(same),len(diff)
# Out:
# (3928, 1927)

# %%
same[0:5]
# Out:
# [[10,
#   '1136921850359848960',
#   "#DhoniKeepsTheGlove | WATCH: Sports Minister Kiren Rijiju issues statement backing MS Dhoni over 'Balidaan Badge', tells BCCI to take up the matter with ICC and keep government in the know as nation's pride is involved\r\n\r\nhttps://t.co/zuo5335Rjr",
#   'NOT\tNone\tNULL'],
#  [11,
#   '1139597122683265026',
#   '@politico No. We should remember very clearly that #Individual1 just admitted to treason . #TrumpIsATraitor  #McCainsAHero #JohnMcCainDay',
#   'HOF\tHATE\tTIN'],
#  [12,
#   '1139476832409944064',
#   '@cricketworldcup Guess who would be the winner of this #CWC19? \r\n\r\nTeam who gets maximum points from the abandoned matches 😄 #ShameOnICC #WIvsENG @ICC',
#   'NOT\tNone\tNULL'],
#  [14,
#   '1140522202300911616',
#   "Corbyn is too politically intellectual for #BorisJohnsonShouldNotBePM \r\nCan't wait \r\n#GeneralElectionNow https://t.co/pt8KmjfxJj",
#   'NOT\tNone\tNULL'],
#  [15,
#   '1139687317394751489',
#   'All the best to #TeamIndia for another swimming competition on Sunday against #Pakistan. \r\n\r\n#INDvPAK #ShameOnICC\r\n#CWC19 #CWC19Rains ☔☔ https://t.co/MG2cIE0zib',
#   'NOT\tNone\tNULL']]

# %%
def preprocess(text):
    return text.replace('\n',' ').replace('\t',' ').replace('\r',' ')
temp_tsv=open('temp_same.tsv','w')
whole_data=''
for row in same:
    row[2]=preprocess(row[2])
    row[0]=str(row[0])
    data='\t'.join(row)+'\n'
    whole_data+=data
temp_tsv.write(whole_data)
temp_tsv.close()

# %%
df_same=pd.read_csv('temp_same.tsv',sep='\t',names=['id','id_str','text','task_1','task_2','task_3'])

# %%
df_same.head()
# Out:
#    id               id_str                                               text  \
# 0  10  1136921850359848960  #DhoniKeepsTheGlove | WATCH: Sports Minister K...
# 1  11  1139597122683265026  @politico No. We should remember very clearly ...
# 2  12  1139476832409944064  @cricketworldcup Guess who would be the winner...
# 3  14  1140522202300911616  Corbyn is too politically intellectual for #Bo...
# 4  15  1139687317394751489  All the best to #TeamIndia for another swimmin...
#
#   task_1 task_2 task_3
# 0    NOT   None    NaN
# 1    HOF   HATE    TIN
# 2    NOT   None    NaN
# 3    NOT   None    NaN
# 4    NOT   None    NaN

# %%
df_same = df_same.replace({pd.np.nan: 'None'})

# %%
df_same.head()
# Out:
#    id               id_str                                               text  \
# 0  10  1136921850359848960  #DhoniKeepsTheGlove | WATCH: Sports Minister K...
# 1  11  1139597122683265026  @politico No. We should remember very clearly ...
# 2  12  1139476832409944064  @cricketworldcup Guess who would be the winner...
# 3  14  1140522202300911616  Corbyn is too politically intellectual for #Bo...
# 4  15  1139687317394751489  All the best to #TeamIndia for another swimmin...
#
#   task_1 task_2 task_3
# 0    NOT   None   None
# 1    HOF   HATE    TIN
# 2    NOT   None   None
# 3    NOT   None   None
# 4    NOT   None   None

# %%
for col in df_same.columns[3:]:
    print(df_same[col].value_counts())
# Out:
# NOT    3130
# HOF     798
# Name: task_1, dtype: int64
# None    3130
# HATE     323
# PRFN     297
# OFFN     178
# Name: task_2, dtype: int64
# None    3130
# TIN      745
# UNT       53
# Name: task_3, dtype: int64

# %%
temp_tsv=open('temp_diff.tsv','w')
whole_data=''
# print(diff[0:5])
for row in diff:
    row[2]=preprocess(row[2])
    row[0]=str(row[0])
    data='\t'.join(row[:4])+'\n'
    whole_data+=data
temp_tsv.write(whole_data)
temp_tsv.close()

# %%
# df_diff=pd.read_csv('temp_diff.tsv',sep='\t',names=['id','id_str','text','user1_task_1','user1_task_2','user1_task_3','user2_task_1','user2_task_2','user2_task_3'])
df_diff=pd.read_csv('temp_diff.tsv',sep='\t',names=['id','id_str','text','user1_task_1','user1_task_2','user1_task_3'])

# %%
df_diff
# Out:
#         id               id_str  \
# 0        7  1140424458991259648
# 1        8  1139542724036694017
# 2        9  1140326741224783872
# 3       13  1139666404150562818
# 4       18  1138658530913902593
# 5       21  1140498832955969536
# 6       24  1139384903261290496
# 7       25  1140240731317161984
# 8       26  1139482207356145665
# 9       27  1139780556114337793
# 10      30  1139329055587753984
# 11      31  1139860224427331586
# 12      33  1139798586319749120
# 13      34  1139537197231747073
# 14      35  1140631342390173696
# 15      38  1140623993487142912
# 16      39  1139185582029119488
# 17      40  1139606106919936000
# 18      41  1139474535131025409
# 19      45  1139642271169753088
# 20      46  1139659132854820864
# 21      50  1137611895341322241
# 22      53  1140254454559776768
# 23      57  1139500031226998785
# 24      59  1139561339699859456
# 25      60  1139832307492122624
# 26      61  1139404002762711040
# 27      62  1140304179589767169
# 28      63  1140625141711290368
# 29      64  1136976405252775937
# ...    ...                  ...
# 1897  5759  1138602141189148672
# 1898  5761  1140277779386327042
# 1899  5763  1140196505606860800
# 1900  5764  1139557524796006405
# 1901  5766  1138443926187192321
# 1902  5767  1140301460061806593
# 1903  5770  1140020744098910208
# 1904  5775  1140122978883112960
# 1905  5776  1139659659529396230
# 1906  5777  1140230607605248005
# 1907  5778  1137354937686302720
# 1908  5779  1139543350946729984
# 1909  5780  1137700347177242624
# 1910  5782  1139649343970009093
# 1911  5783  1138880218263769088
# 1912  5785  1139241942624165888
# 1913  5786  1137744539144282113
# 1914  5788  1139717188938416128
# 1915  5789  1139491464558206977
# 1916  5792  1140113853570834432
# 1917  5793  1140410865382019072
# 1918  5794  1139362717452689408
# 1919  5795  1139463013344223232
# 1920  5801  1139538460090331136
# 1921  5803  1137949424288591872
# 1922  5804  1140445706777440257
# 1923  5806  1139542498899107841
# 1924  5807  1139587426509193216
# 1925  5810  1139177728903700481
# 1926  5811  1139901581049171968
#
#                                                    text user1_task_1  \
# 0     @RossThomson_MP Imitation of a tweet, flattery...          NOT
# 1     @Sarah_SKG_1983 The beach is calling! Weekend ...          HOF
# 2     It's clear to see why @BorisJohnson has not ta...          HOF
# 3     @funder #JohnMcCainDay Thanks for fund raising...          HOF
# 4     @kenjilopezalt Was it the frozen meal line, th...          HOF
# 5     He will metaphorically hang himself all on his...          HOF
# 6     A billion Cricket fans waited four years to wa...          HOF
# 7     This is what I hate most about politics today:...          HOF
# 8     Happy #JohnMcCainDay #JohnMcCainDayJune14th   ...          NOT
# 9     Dr. Kafeel arranged oxygen cylinders with his ...          HOF
# 10    How do you say 'Gulf of Tonkin' in 2019? Oh ye...          HOF
# 11    @psarkar2111 We need correct action from docto...          NOT
# 12    What is stopping Modi Govt To Impose president...          NOT
# 13    Benedict Arnold used debt and being passed ove...          HOF
# 14    Next in line to the Tory dictatorship, BoJo, w...          HOF
# 15    Hey ...Michael “Dog Killer”Heseltine, what do ...          HOF
# 16    @LindseyGrahamSC You should have stopped here,...          HOF
# 17    #ShameOnICC u cheated all cricket fans.. cance...          HOF
# 18    Dear #icc on 16th June 2019 decide whether we ...          HOF
# 19    Trumpkin’s are clutching their hypocrisy pearl...          HOF
# 20    @realDonaldTrump And you #TrumpLiesEveryTimeHe...          HOF
# 21    Dear @ICC Offering namaz on field is not a big...          HOF
# 22    @realDonaldTrump The NYT has been around long ...          HOF
# 23    If tonight @MamataOfficial has a stroke, who i...          HOF
# 24    Wasn't that the point?   #TrumpIsATraitor http...          NOT
# 25    Stop violence against Doctors. #DoctorsFightBa...          NOT
# 26    Real Talk:    If you support @realDonaldTrump ...          HOF
# 27    #DefeatGOPin2020  #DictatorTrump #ImpeachmentI...          HOF
# 28    'Yes, I think that for all politicians the tho...          HOF
# 29    ICC is not God. If we give in today then tomor...          HOF
# ...                                                 ...          ...
# 1897  Really is that why fox cut you off when you zt...          HOF
# 1898  @TheRealOJ32 Still looking for the real killer...          NOT
# 1899  @DOlusegun @elrufai Hope they don't becomes #D...          NOT
# 1900  @gtconway3d @KellyannePolls @realDonaldTrump H...          NOT
# 1901  @briantylercohen @mattgaetz is such a #doucheb...          HOF
# 1902  @washingtonpost This is something everyone sho...          NOT
# 1903  Sorry about that. Has anybody got a #dickhead ...          NOT
# 1904  You know, I really want to tweet something neg...          HOF
# 1905  @realDonaldTrump @senatemajldr @MarkWarner No ...          HOF
# 1906  @AprilDRyan I wouldn't want him following me. ...          HOF
# 1907  @mpvadodara Mam. Pls don't promote a Private U...          HOF
# 1908  @polisands @GOP @realDonaldTrump I’m sorry you...          HOF
# 1909  What's the deal with Griezmann and his way of ...          HOF
# 1910  @TeeTweetsHere @CNN @MSNBC @mkraju @AliVelshi ...          HOF
# 1911  @blocthot Hey Binx, fuck what that asshat thin...          HOF
# 1912  @realDonaldTrump @K1erry No surprise there. Wa...          HOF
# 1913  @ImranKhanPTI if u and ur govt have little sha...          HOF
# 1914  @realDonaldTrump is Putin’s Puppet!   #TrumpsW...          HOF
# 1915  Full of fools.. ICC @ICCMediaComms @ICC @crick...          HOF
# 1916  @TheRealOJ32 You’re really stabbin...er, grabb...          HOF
# 1917  The US-Mexican border, where established moral...          HOF
# 1918  @RepAdamSchiff I seem to remember a radio show...          HOF
# 1919  @ICC All Eng matches are on dry pitches &amp; ...          HOF
# 1920  It seems the Rain &amp; thunder god only like ...          HOF
# 1921  #Muslim #Rapist Raped 28 #innocent #Girls in 1...          HOF
# 1922  @davidfrum @trueblueusa1 That's cute and all, ...          HOF
# 1923  a recession issa comin' #maga #magamyass #fuck...          NOT
# 1924  #DoctorsFightBack  Will 'The Mad n Irrational ...          HOF
# 1925  #ShiningIndia #educatedindia or more like RUND...          HOF
# 1926  Could this be our new Prime Minister?     #Ric...          HOF
#
#      user1_task_2 user1_task_3
# 0            None          NaN
# 1            HATE          TIN
# 2            HATE          TIN
# 3            OFFN          TIN
# 4            PRFN          TIN
# 5            OFFN          TIN
# 6            HATE          TIN
# 7            PRFN          UNT
# 8            None          NaN
# 9            HATE          TIN
# 10           HATE          TIN
# 11           None          NaN
# 12           None          NaN
# 13           HATE          TIN
# 14           HATE          TIN
# 15           HATE          TIN
# 16           HATE          TIN
# 17           HATE          TIN
# 18           HATE          TIN
# 19           HATE          TIN
# 20           HATE          TIN
# 21           HATE          TIN
# 22           HATE          TIN
# 23           HATE          TIN
# 24           None          NaN
# 25           None          NaN
# 26           PRFN          UNT
# 27           HATE          TIN
# 28           HATE          TIN
# 29           HATE          TIN
# ...           ...          ...
# 1897         PRFN          TIN
# 1898         None          NaN
# 1899         None          NaN
# 1900         None          NaN
# 1901         OFFN          TIN
# 1902         None          NaN
# 1903         None          NaN
# 1904         HATE          TIN
# 1905         HATE          TIN
# 1906         HATE          UNT
# 1907         HATE          UNT
# 1908         HATE          TIN
# 1909         PRFN          UNT
# 1910         HATE          TIN
# 1911         PRFN          UNT
# 1912         PRFN          TIN
# 1913         OFFN          TIN
# 1914         HATE          TIN
# 1915         HATE          TIN
# 1916         OFFN          TIN
# 1917         HATE          TIN
# 1918         PRFN          TIN
# 1919         HATE          TIN
# 1920         HATE          TIN
# 1921         HATE          UNT
# 1922         PRFN          UNT
# 1923         None          NaN
# 1924         OFFN          TIN
# 1925         OFFN          UNT
# 1926         PRFN          UNT
#
# [1927 rows x 6 columns]

# %%
df_diff = df_diff.replace({pd.np.nan: 'None'})
df_diff.head(10)
# Out:
#    id               id_str                                               text  \
# 0   7  1140424458991259648  @RossThomson_MP Imitation of a tweet, flattery...
# 1   8  1139542724036694017  @Sarah_SKG_1983 The beach is calling! Weekend ...
# 2   9  1140326741224783872  It's clear to see why @BorisJohnson has not ta...
# 3  13  1139666404150562818  @funder #JohnMcCainDay Thanks for fund raising...
# 4  18  1138658530913902593  @kenjilopezalt Was it the frozen meal line, th...
# 5  21  1140498832955969536  He will metaphorically hang himself all on his...
# 6  24  1139384903261290496  A billion Cricket fans waited four years to wa...
# 7  25  1140240731317161984  This is what I hate most about politics today:...
# 8  26  1139482207356145665  Happy #JohnMcCainDay #JohnMcCainDayJune14th   ...
# 9  27  1139780556114337793  Dr. Kafeel arranged oxygen cylinders with his ...
#
#   user1_task_1 user1_task_2 user1_task_3
# 0          NOT         None         None
# 1          HOF         HATE          TIN
# 2          HOF         HATE          TIN
# 3          HOF         OFFN          TIN
# 4          HOF         PRFN          TIN
# 5          HOF         OFFN          TIN
# 6          HOF         HATE          TIN
# 7          HOF         PRFN          UNT
# 8          NOT         None         None
# 9          HOF         HATE          TIN

# %%
for col in df_diff.columns[3:]:
    print(df_diff[col].value_counts())
# Out:
# HOF    1448
# NOT     479
# Name: user1_task_1, dtype: int64
# HATE    818
# None    479
# PRFN    369
# OFFN    261
# Name: user1_task_2, dtype: int64
# TIN     1282
# None     479
# UNT      166
# Name: user1_task_3, dtype: int64

# %% [markdown]
# # German

# %%
import json
import sqlite3
import pandas as pd
conn_final = sqlite3.connect('../../hasoc_german/hasoc_final_13.db')
cursor_final=conn_final.cursor()
cursor_final.execute('SELECT * FROM annoted_tweets')

# %%
german_tweets=cursor_final.fetchall()
len(german_tweets)
# Out:
# 3819

# %%
def clean_data(data):
    data_clean = []
    # print(li)
    for row in data:
        row_li = list(row)
        for column in row_li:
            if column == None:
                row_li.remove(column)
            else:
                pass
        data_clean.append(row_li)

    final_data = []
    count_double = 0
    for data in data_clean:
        updated = [d for d in data if d and d != 'None']
        if len(updated[3:]) > 2:
            # print(updated[1], updated[3:-1])
            count_double += 1
        final_data.append(updated[:])
#     print('double count', count_double)
    return final_data, count_double
def get_same_annots(data):
    same_annots = []
    diff_annots=[]
    count_double = 0
#     print(data[0])
    count_same=0
    for row in data:
        row_unique = []
#         if len(row) > 3:
        count_double += 1
        row_unique += row
        set_judgement = set(row[3:])
#         print(len(row))
        if len(set_judgement) == 1 and len(row)==5:
            set_judgement = list(set_judgement)
            print(row[3:],set_judgement)
            row_unique.append(set_judgement[0])
            same_annots.append(row_unique[0:4])
            count_same+=1
        else:
#             print(row_unique[:4])
            diff_annots.append(row_unique[:4])
    print(count_double,count_same)
    print(diff_annots[0])
    return same_annots,diff_annots

# %%
german_tweets=clean_data(german_tweets)[0]
same,diff=get_same_annots(german_tweets)
# Out:
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tPRFN\tNULL', 'HOF\tPRFN\tNULL'] ['HOF\tPRFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['HOF\tHATE\tNULL', 'HOF\tHATE\tNULL'] ['HOF\tHATE\tNULL']
# ['HOF\tOFFN\tNULL', 'HOF\tOFFN\tNULL'] ['HOF\tOFFN\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# ['NOT\tNone\tNULL', 'NOT\tNone\tNULL'] ['NOT\tNone\tNULL']
# 3819 996
# [1451, '1135978356300746752', 'RuW: Roland Wuttke – Nationale Selbstbestimmung in\xa0Europa https://t.co/Ascoe8vXDj', 'NOT\tNone\tNULL']

# %%
len(same),len(diff)
# Out:
# (996, 2823)

# %%
diff[0]
# Out:
# [1451,
#  '1135978356300746752',
#  'RuW: Roland Wuttke – Nationale Selbstbestimmung in\xa0Europa https://t.co/Ascoe8vXDj',
#  'NOT\tNone\tNULL']

# %%
final=same+diff

# %%
len(final)
# Out:
# 3819

# %%
placeholder='hasoc_de_'
count=1
final_data=''
for row in final:
    rid='{}{}'.format(placeholder,count)
    text=row[2].replace('\n',' ').replace('\r',' ').replace('\t',' ')
    result=row[-1].split('\t')
    if result[1]=='None':
        result[1]='NULL'
    result='\t'.join(result[:])
    file_row='\t'.join([rid,text,result])+'\n'
    final_data+=file_row
    count+=1

# %%
german_data=open('../../hasoc_german/final_dataset.tsv','w')
german_data.write(final_data)
german_data.close()

# %% [markdown]
# # English tsv to df

# %%
df_english=pd.read_csv('final_test.tsv',sep='\t')

# %%
df_english.head()
# Out:
#    id               tweet_id  \
# 0  10  1.13692185035985E+018
# 1  11  1.13959712268327E+018
# 2  12  1.13947683240994E+018
# 3  14  1.14052220230091E+018
# 4  15  1.13968731739475E+018
#
#                                                 text task_1 task_2 task_3
# 0  #DhoniKeepsTheGlove | WATCH: Sports Minister K...    NOT   None    NaN
# 1  @politico No. We should remember very clearly ...    HOF   HATE    TIN
# 2  @cricketworldcup Guess who would be the winner...    NOT   None    NaN
# 3  Corbyn is too politically intellectual for #Bo...    NOT   None    NaN
# 4  All the best to #TeamIndia for another swimmin...    NOT   None    NaN

# %%
df_english.loc[df_english["task_2"]=='None',"task_2",]='NONE'
df_english = df_english.replace({pd.np.nan: 'NONE'})

# %%
df_english.head()
# Out:
#    id               tweet_id  \
# 0  10  1.13692185035985E+018
# 1  11  1.13959712268327E+018
# 2  12  1.13947683240994E+018
# 3  14  1.14052220230091E+018
# 4  15  1.13968731739475E+018
#
#                                                 text task_1 task_2 task_3
# 0  #DhoniKeepsTheGlove | WATCH: Sports Minister K...    NOT   NONE   NONE
# 1  @politico No. We should remember very clearly ...    HOF   HATE    TIN
# 2  @cricketworldcup Guess who would be the winner...    NOT   NONE   NONE
# 3  Corbyn is too politically intellectual for #Bo...    NOT   NONE   NONE
# 4  All the best to #TeamIndia for another swimmin...    NOT   NONE   NONE

# %%
set(df_english.task_1),set(df_english.task_2),set(df_english.task_3)
# Out:
# ({'HOF', 'NOT'}, {'HATE', 'NONE', 'OFFN', 'PRFN'}, {'NONE', 'TIN', 'UNT'})

# %%
len(df_english)
# Out:
# 5852

# %%
placeholder_en='hasoc_en_'
count=1
rids=['{}{}'.format(placeholder_en,count) for count in range(1,len(df_english)+1)]

# %%
len(rids)
# Out:
# 5852

# %%
df_english['tweet_id']=rids
del df_english['id']

# %%
df_english.head()
# Out:
#      tweet_id                                               text task_1  \
# 0  hasoc_en_1  #DhoniKeepsTheGlove | WATCH: Sports Minister K...    NOT
# 1  hasoc_en_2  @politico No. We should remember very clearly ...    HOF
# 2  hasoc_en_3  @cricketworldcup Guess who would be the winner...    NOT
# 3  hasoc_en_4  Corbyn is too politically intellectual for #Bo...    NOT
# 4  hasoc_en_5  All the best to #TeamIndia for another swimmin...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
df_english.to_csv('final_english.tsv',sep='\t',index=False)

# %% [markdown]
# # Verify Datasets
# # English

# %%
df_eng=pd.read_csv('final_english_dataset.tsv',sep='\t')

# %%
df_eng.head()
# Out:
#      tweet_id                                               text task_1  \
# 0  hasoc_en_1  #DhoniKeepsTheGlove | WATCH: Sports Minister K...    NOT
# 1  hasoc_en_2  @politico No. We should remember very clearly ...    HOF
# 2  hasoc_en_3  @cricketworldcup Guess who would be the winner...    NOT
# 3  hasoc_en_4  Corbyn is too politically intellectual for #Bo...    NOT
# 4  hasoc_en_5  All the best to #TeamIndia for another swimmin...    NOT
#
#   task_2 task_3
# 0   NONE   NONE
# 1   HATE    TIN
# 2   NONE   NONE
# 3   NONE   NONE
# 4   NONE   NONE

# %%
total_not=0
check=0
check2=0
for row in range(len(df_eng)):
    task1=df_eng.loc[row]['task_1']
    task2=df_eng.loc[row]['task_2']
    task3=df_eng.loc[row]['task_3']
    if task1=='NOT':
        total_not+=1
    if task1=='NOT' and task2=='NONE' and task3=='NONE':
        check+=1
    if task2 in ['HATE','OFFN','PRFN'] and task3 in ['UNT','TIN']:
        check2+=1
    elif task2 in ['HATE','OFFN','PRFN'] and task3 not in ['UNT','TIN']:
        print(df_eng.loc[row])
print(total_not,check,check2)
# Out:
# 3591 3591 2261

# %%
df_eng['task_3'].value_counts()
# Out:
# NONE    3591
# TIN     2041
# UNT      220
# Name: task_3, dtype: int64

# %%
df_eng.to_csv('final_english_dataset.tsv',sep='\t',index=False)

# %% [markdown]
# # German

# %%
df_de=pd.read_csv('../../hasoc_german/final_dataset.tsv',sep='\t')
df_de = df_de.replace({pd.np.nan: 'NONE'})

# %%
del df_de['task_3']

# %%
df_de.head(20)
# Out:
#         text_id                                               text task_1  \
# 0    hasoc_de_1  Frank Rennicke – Ich bin stolz https://t.co/Cm...    NOT
# 1    hasoc_de_2  ANSEHEN.....und danach bitte TEILEN...TEILEN.....    NOT
# 2    hasoc_de_3  #Koeln Mohamed erkennt kein deutsches Recht so...    NOT
# 3    hasoc_de_4  #SaudiArabien ist eine brutale islamische Dikt...    NOT
# 4    hasoc_de_5  Bundespolizei #München hat im 1. Quartal 2019 ...    NOT
# 5    hasoc_de_6  #1EuropaFuerAlle oder wie es die #SPD heute no...    NOT
# 6    hasoc_de_7  #Hannover: Weil ihm die Freizeitgestaltung und...    NOT
# 7    hasoc_de_8  #Deutschland 2019: Ort für die #EU-Wahlparty d...    NOT
# 8    hasoc_de_9  #Innsbruck: Tirolerin und Türke knacken 2018 z...    NOT
# 9   hasoc_de_10  #Wien: Vier Nigerianer bestellen teils hochpre...    NOT
# 10  hasoc_de_11  #Offenburg: Somalier greift nachts auf der Str...    NOT
# 11  hasoc_de_12  #Offenburg: Die Attacke des 2015 nach D gekomm...    NOT
# 12  hasoc_de_13  Kapazitäten im ZDF und zur Eurowahl: Den Islam...    NOT
# 13  hasoc_de_14  mdr Umfrage 'Gehört der Islam zu Deutschland?'...    NOT
# 14  hasoc_de_15  Da musste der Moderator wohl 2 mal hinschauen ...    NOT
# 15  hasoc_de_16  EU-Kommissar Frans #Timmermans sagt, der Islam...    NOT
# 16  hasoc_de_17  Wenn ein #Syrer den @Die_Gruenen erzählt, dass...    NOT
# 17  hasoc_de_18  #Berlin: Ibrahima D. (24) von der Elfenbeinküs...    NOT
# 18  hasoc_de_19  IS-Terror-Verdächtiger Salafist in #Koeln fest...    NOT
# 19  hasoc_de_20  Einreise per Flugzeug: Regierung erklärt Flüch...    NOT
#
#    task_2
# 0    NONE
# 1    NONE
# 2    NONE
# 3    NONE
# 4    NONE
# 5    NONE
# 6    NONE
# 7    NONE
# 8    NONE
# 9    NONE
# 10   NONE
# 11   NONE
# 12   NONE
# 13   NONE
# 14   NONE
# 15   NONE
# 16   NONE
# 17   NONE
# 18   NONE
# 19   NONE

# %%
total_not=0
check=0
check2=0
for row in range(len(df_de)):
    task1=df_de.loc[row]['task_1']
    task2=df_de.loc[row]['task_2']
    if task1=='NOT':
        total_not+=1
    if task1=='NOT' and task2 != 'NONE':
        df_de.loc[row]['task_2']='NONE'
print(total_not,check)
# Out:
# 3412 0

# %%
df_de['task_1'].value_counts()
# Out:
# NOT    3412
# HOF     407
# Name: task_1, dtype: int64

# %%
df_de.to_csv('../../hasoc_german/final_dataset_checked.tsv',sep='\t',index=False)

# %%
emails_all='''louis.lv.info@gmail.com
smishra8@illinois.edu
sattam.almatarneh@gmail.com
prem.jb@gmail.com
kk@gauhati.ac.in
cs18resch11003@iith.ac.in
druiter@lsv.uni-saarland.de
muhammad.rafi@nu.edu.pk
haritha99.ananth@gmail.com
antonios.anagnostou@factmata.com
aiqi.jiang@yahoo.com
vmujadia@gmail.com
vivek.a@research.iiit.ac.in
27ankitsharma@gmail.com
dinesh.nitr@gmail.com
supriyachanda.rs.cse18@itbhu.ac.in
hamada.ali@fci.bu.edu.eg
m1.bashar@qut.edu.au
nikhil.pinnaparaju@research.iiit.ac.in
utpal.sikdar@gmail.com
punyajoysaha1998@gmail.com
arup.baruah@gmail.com
jean-christophe.mensonides@mines-ales.fr
allaith.net@gmail.com
marcocasavantes@gmail.com
ghosh.koyel8@gmail.com
kingshukbasak.1992@gmail.com
apurbalal.senapati@gmail.com
apurbalal.senapati@gmail.com
pruthwik.mishra@research.iiit.ac.in
groutar@gmail.com
hammad.afzal@mcs.edu.pk
ayushsuhane99@iitkgp.ac.in
mgcalderon@outlook.es
ghosh.koyel8@gmail.com
akanksham.rs.cse17@itbhu.ac.in
anitas.rs.cse16@itbhu.ac.in
rahul.sharma.met16@itbhu.ac.in
rahul.meena.met16@itbhu.ac.in
kartikaggarwal98@gmail.com
santoshk.du@gmail.com
abhinavnagpal12@gmail.com
kingshukbasak.1992@gmail.com
varsha.redla@students.iiit.ac.in
varsha.redla@students.iiit.ac.in
ammaslaskhmy@gmail.com
18883859616@163.com
ynudyx@gmail.com
apurvakparikh@gmail.com
manuel.saravia@fing.edu.uy
sharmiladevi1002@gmail.com
rahul.sharma.met16@itbhu.ac.in
ilia.markov@uantwerpen.be
andrei.paraschiv74@stud.acs.upb.ro
f20170080@pilani.bits-pilani.ac.in
p20180437@pilani.bits-pilani.ac.in
bhartigoel0812@gmail.com
kirti.cse15@nitp.ac.in
kirti.cse15@nitp.ac.in
T.D.RanasingheHettiarachchige@wlv.ac.uk
georgios.pitsilis@ntnu.no
dubey.abhijeet09@gmail.com
cs17resch11006@iith.ac.in
vi.ma.ni.os00@gmail.com
vi.ma.ni.os00@gmail.com
shyhuangq@gmail.com
anitas.rs.cse16@itbhu.ac.in
nehagupta2885@gmail.com
abhilash.gunasegaran@gmail.com
beattymg@gmail.com
smsarwar@cs.umass.edu'''

# %%
emails_all=emails_all.split('\n')

# %%
emails_sent='''louis.lv.info@gmail.com,
smishra8@illinois.edu,
sattam.almatarneh@gmail.com,
prem.jb@gmail.com,
kk@gauhati.ac.in,
Kaushal Kumar Maurya <cs18resch11003@iith.ac.in>,
druiter@lsv.uni-saarland.de,
muhammad.rafi@nu.edu.pk,
haritha99.ananth@gmail.com,
antonios.anagnostou@factmata.com,
aiqi.jiang@yahoo.com,
vmujadia@gmail.com,
Vivek Anand <vivek.a@research.iiit.ac.in>,
27ankitsharma@gmail.com,
dinesh.nitr@gmail.com,
supriyachanda.rs.cse18@itbhu.ac.in,
hamada.ali@fci.bu.edu.eg,
m1.bashar@qut.edu.au,
Nikhil Pinnaparaju <nikhil.pinnaparaju@research.iiit.ac.in>,
Utpal Sikdar <utpal.sikdar@gmail.com>,
Punyajoy saha <punyajoysaha1998@gmail.com>,
Arup Baruah <arup.baruah@gmail.com>,
Jean-Christophe MENSONIDES <jean-christophe.mensonides@mines-ales.fr>,
Ali Al-laith <allaith.net@gmail.com>,
Marco Casavantes <marcocasavantes@gmail.com>,
Nill Koyel Ghosh <ghosh.koyel8@gmail.com>,
KINGSHUK BASAK <kingshukbasak.1992@gmail.com>,
Apurbalal Senapati <apurbalal.senapati@gmail.com>,
Pruthwik Mishra <pruthwik.mishra@research.iiit.ac.in>,
Guilherme Routar <groutar@gmail.com>,
Hammad Afzal <hammad.afzal@mcs.edu.pk>,
Ayush Suhane <ayushsuhane99@iitkgp.ac.in>,
mgcalderon@outlook.es,
akanksham.rs.cse17@itbhu.ac.in,
anitas.rs.cse16@itbhu.ac.in,
rahul.sharma.met16@itbhu.ac.in,
rahul.meena.met16@itbhu.ac.in,
kartikaggarwal98@gmail.com,
Santosh Kumar <santoshk.du@gmail.com>,
abhinavnagpal12@gmail.com,
varsha.redla@students.iiit.ac.in,
ammaslaskhmy@gmail.com,
王斌 <18883859616@163.com>,
Yunxia Ding <ynudyx@gmail.com>,
apurvakparikh@gmail.com,
manuel.saravia@fing.edu.uy,
Sharmila devi <sharmiladevi1002@gmail.com>,
ilia.markov@uantwerpen.be,
andrei.paraschiv74@stud.acs.upb.ro,
f20170080@pilani.bits-pilani.ac.in,
p20180437@pilani.bits-pilani.ac.in,
bhartigoel0812@gmail.com,
kirti.cse15@nitp.ac.in,
T.D.RanasingheHettiarachchige@wlv.ac.uk,
georgios.pitsilis@ntnu.no,
Abhijeet Dubey <dubey.abhijeet09@gmail.com>,
cs17resch11006@iith.ac.in,
vi.ma.ni.os00@gmail.com,
shyhuangq@gmail.com,
nehagupta2885@gmail.com,
abhilash.gunasegaran@gmail.com,
beattymg@gmail.com'''

# %%
clean_sent=[]
for user in emails_sent.split(','):
    split=user.split(' ')
    if len(split)==1:
        clean_sent.append(split[0].strip())
        print('if',split[0])
    else:
        clean_sent.append(split[-1].split(' ')[-1][1:-1])
# Out:
# if louis.lv.info@gmail.com
# if
# smishra8@illinois.edu
# if
# sattam.almatarneh@gmail.com
# if
# prem.jb@gmail.com
# if
# kk@gauhati.ac.in
# if
# druiter@lsv.uni-saarland.de
# if
# muhammad.rafi@nu.edu.pk
# if
# haritha99.ananth@gmail.com
# if
# antonios.anagnostou@factmata.com
# if
# aiqi.jiang@yahoo.com
# if
# vmujadia@gmail.com
# if
# 27ankitsharma@gmail.com
# if
# dinesh.nitr@gmail.com
# if
# supriyachanda.rs.cse18@itbhu.ac.in
# if
# hamada.ali@fci.bu.edu.eg
# if
# m1.bashar@qut.edu.au
# if
# mgcalderon@outlook.es
# if
# akanksham.rs.cse17@itbhu.ac.in
# if
# anitas.rs.cse16@itbhu.ac.in
# if
# rahul.sharma.met16@itbhu.ac.in
# if
# rahul.meena.met16@itbhu.ac.in
# if
# kartikaggarwal98@gmail.com
# if
# abhinavnagpal12@gmail.com
# if
# varsha.redla@students.iiit.ac.in
# if
# ammaslaskhmy@gmail.com
# if
# apurvakparikh@gmail.com
# if
# manuel.saravia@fing.edu.uy
# if
# ilia.markov@uantwerpen.be
# if
# andrei.paraschiv74@stud.acs.upb.ro
# if
# f20170080@pilani.bits-pilani.ac.in
# if
# p20180437@pilani.bits-pilani.ac.in
# if
# bhartigoel0812@gmail.com
# if
# kirti.cse15@nitp.ac.in
# if
# T.D.RanasingheHettiarachchige@wlv.ac.uk
# if
# georgios.pitsilis@ntnu.no
# if
# cs17resch11006@iith.ac.in
# if
# vi.ma.ni.os00@gmail.com
# if
# shyhuangq@gmail.com
# if
# nehagupta2885@gmail.com
# if
# abhilash.gunasegaran@gmail.com
# if
# beattymg@gmail.com

# %%
for email in set(emails_all):
    if email not in clean_sent:
        print(email)
# Out:
# smsarwar@cs.umass.edu
